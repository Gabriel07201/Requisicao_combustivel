# %%
import pandas as pd
banco = pd.read_excel(r'C:\Users\Gabriel\Desktop\Programação\Requisicao_combustivel\banco_de_dados.xlsx')
banco
# Out:
#     ID Solicitante Motorista       Categoria  Quantidade  Preço Unitário  \
# 0    1     Gabriel   Gabriel           Teste         0.0             0.0
# 1    2     Adilson   Adilson        Gasolina         3.0             NaN
# 2    3     Adilson   Gabriel  Filtro de óleo         3.0             3.0
# 3    4    Gemerson   Adilson  Filtro de óleo         3.0             3.0
# 4    5     Adilson   Adilson          Etanol         5.0             5.0
# 5    6     Adilson   Adilson    Filtro de ar         NaN             NaN
# 6    7    Gemerson   Adilson  Filtro de óleo         NaN             NaN
# 7    8    Gemerson   Adilson  Filtro de óleo         NaN             NaN
# 8    9     Adilson   Adilson  Filtro de óleo         NaN             NaN
# 9   10     Adilson   Adilson          Etanol         3.0             3.0
# 10  11    Gemerson   Adilson          Etanol         NaN             NaN
# 11  12     Adilson  Gemerson  Filtro de óleo         NaN             NaN
# 12  13     Adilson  Gemerson  Filtro de óleo         NaN             NaN
# 13  14     Gabriel   Adilson          Etanol         3.0             3.0
# 14  15    Gemerson   Adilson        Gasolina         NaN             NaN
# 15  16     Adilson  Gemerson        Gasolina         NaN           100.0
# 16  17     Adilson   Adilson          Etanol         NaN             NaN
# 17  18     Adilson   Adilson    Filtro de ar         NaN             NaN
# 18  19    Gemerson  Gemerson          Etanol         NaN             NaN
# 19  20     Adilson   Adilson  Filtro de óleo         NaN             NaN
#
#     Total                 Data                       Observação
# 0       0  2022-11-23 00:00:00        Teste para buscar valores
# 1       9           23/11/2022                              NaN
# 2       9           23/11/2022           teste arrumado colunas
# 3       9           23/11/2022                 teste do refresh
# 4      25           23/11/2022                              NaN
# 5       0           23/11/2022                              NaN
# 6       0           23/11/2022                              NaN
# 7       0           23/11/2022                              NaN
# 8       0           23/11/2022                              NaN
# 9       9           23/11/2022  teste com banco detro da classe
# 10      0           23/11/2022                              NaN
# 11      0           28/11/2022                              NaN
# 12      0           28/11/2022                              NaN
# 13      9           28/11/2022                              NaN
# 14      0           28/11/2022                              NaN
# 15      0           28/11/2022                              NaN
# 16      0           28/11/2022                              NaN
# 17      0           28/11/2022                              NaN
# 18      0           28/11/2022                              NaN
# 19      0           28/11/2022                              NaN

# %%
selecao = banco['ID'] == 1
busca = banco[selecao]
lista = list(busca['Solicitante'])
print(lista[0])
print(type(lista[0]))
# Out:
# Gabriel
# <class 'str'>

# %%
for coluna in banco:
    selecao = banco['ID'] == 3
    busca = banco[selecao]
    lista = list(busca[coluna])
    if coluna == 'Solicitante':
        print(coluna)
# Out:
# Solicitante

# %%
banco['Observação'].isnull()
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9     False
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# Name: Observação, dtype: bool
